# %% [markdown]
# <a href="https://colab.research.google.com/github/InsightEdge01/AIJobInterviewPrepBot/blob/master/Crawl4ai_Markdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install "crawl4ai @ git+https://github.com/unclecode/crawl4ai.git"

# %%
from crawl4ai import WebCrawler

# %%
#create an instance of crawler
crawler = WebCrawler()
# Out:
# [LOG] 🚀 Initializing LocalSeleniumCrawlerStrategy

# %%
#Warm up the crawler (load necessary models)
crawler.warmup()
# Out:
# [LOG] 🌤️  Warming up the WebCrawler
# [LOG] 🌞 WebCrawler is ready to crawl

# %%
url = "https://www.dataedgehub.com/2024/09/building-and-deploying-full-stack.html"
#url = "https://www.nbcnews.com/business"
result = crawler.run(url)

print(result.markdown)
# Out:
# [LOG] 🚀 Crawling done for https://www.dataedgehub.com/2024/09/building-and-deploying-full-stack.html, success: True, time taken: 1.688295841217041 seconds
# [LOG] 🚀 Content extracted for https://www.dataedgehub.com/2024/09/building-and-deploying-full-stack.html, success: True, time taken: 0.06094837188720703 seconds
# [LOG] 🔥 Extracting semantic blocks for https://www.dataedgehub.com/2024/09/building-and-deploying-full-stack.html, Strategy: NoExtractionStrategy
# [LOG] 🚀 Extraction done for https://www.dataedgehub.com/2024/09/building-and-deploying-full-stack.html, time taken: 0.06251025199890137 seconds.
# Skip to main content
#
# ###  Search This Blog
#
# #  Data Edge Hub
#
# ###  Building and Deploying Full-Stack Applications in Seconds with Aider and
# Replit
#
#   * Get link
#   * Facebook
#   * Twitter
#   * Pinterest
#   * Email
#   * Other Apps
#
# September 03, 2024
#
# In today’s fast-paced development landscape, the ability to rapidly build and
# ...
